# %%
import pandas as pd
from sklearn import tree
#from sklearn import DecisionTreeRegressor
import os
import numpy

# %%
df = pd.read_csv('data/master_dataset_float.csv', encoding="ISO-8859-1")
df.head(10)
# Out:
#    row                                       track  acousticness  \
# 0  0.0                          I Want It That Way      0.216000
# 1  1.0                                 Bye Bye Bye      0.040800
# 2  2.0                                     Wannabe      0.101000
# 3  3.0             I'll Be Missing You (feat. 112)      0.052200
# 4  4.0  Everybody (Backstreet's Back) - Radio Edit      0.035200
# 5  5.0             All I Want for Christmas Is You      0.164000
# 6  6.0                                  Wonderwall      0.000807
# 7  7.0                                      Zombie      0.016300
# 8  8.0             Black or White - Single Version      0.082400
# 9  9.0                                        Iris      0.001250
#
#    danceability  duration_ms  energy                      id  \
# 0         0.689       213600   0.702  6e40mgJiCid5HRAGrbpGA6
# 1         0.614       200560   0.928  4r8lRYnoOGdEi6YyI5OC1o
# 2         0.768       173027   0.864  1Je1IMUlBXcx1Fz0WE7oPT
# ...

# %%
X = df[["energy", "instrumentalness", "liveness", "loudness", "speechiness", "tempo"]]
y = df["danceability"].values.reshape(-1, 1)
#y = df["danceability"]
print(X.shape, y.shape)
# Out:
# (5341, 6) (5341, 1)

# %%
X.head(10)
# Out:
#    energy  instrumentalness  liveness  loudness  speechiness    tempo
# 0   0.702          0.000000    0.1590    -5.642       0.0261   99.031
# 1   0.928          0.001040    0.0845    -4.806       0.0516  172.656
# 2   0.864          0.000000    0.1620    -6.145       0.0324  110.008
# 3   0.479          0.001260    0.5890    -9.199       0.0646  109.878
# 4   0.853          0.000000    0.2680    -4.219       0.0363  108.016
# 5   0.625          0.000000    0.0708    -7.462       0.0386  150.277
# 6   0.892          0.000000    0.2070    -4.373       0.0336  174.426
# 7   0.613          0.003590    0.3680    -9.012       0.0347  166.960
# 8   0.894          0.052700    0.0890    -3.826       0.0495  114.869
# 9   0.715          0.000008    0.0942    -8.072       0.0362  155.925

# %%
y.head(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-4291aba0a744> in <module>()
# ----> 1 y.head(10)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
X_train.head(10)
# Out:
#       energy  instrumentalness  liveness  loudness  speechiness    tempo
# 4885   0.764          0.000094    0.0543    -4.399       0.0380  121.958
# 2899   0.659          0.000000    0.1330    -5.234       0.0824   87.539
# 5009   0.830          0.000000    0.0865    -4.918       0.0404   90.028
# 3941   0.457          0.000000    0.1050    -8.322       0.0468  150.953
# 3831   0.631          0.000000    0.0911    -4.798       0.0304  143.846
# 1485   0.519          0.000000    0.1220    -7.207       0.0265   99.999
# 4335   0.395          0.000000    0.2950    -8.622       0.0332  133.296
# 3277   0.740          0.000000    0.0992    -4.566       0.2830  130.040
# 3379   0.774          0.000000    0.2810    -2.459       0.3000   79.745
# 5149   0.819          0.000000    0.1150    -4.350       0.3850   94.984

# %%
clf = tree.DecisionTreeRegressor()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# -0.13013041391110924
