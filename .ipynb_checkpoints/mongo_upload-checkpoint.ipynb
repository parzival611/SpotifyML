# %%
# Move data in MongoDB/MLAB
import pymongo
from pymongo import MongoClient
mongo_uri = 'mongodb://admin:yaybootcamp2018@ds231228.mlab.com:31228/songs_ml'
conn = MongoClient(mongo_uri)
db = conn.songs_ml
collection_songs = db.songs

# %%
import pandas as pd
df = pd.read_excel('data/master_spotify_float.xlsx', encoding="ISO-8859-1")
df = df.drop(columns=['row', 'id', 'time_signature', 'track_href'])
df.head()
# Out:
#                                         track  acousticness  danceability  \
# 0                          I Want It That Way        0.2160         0.689
# 1                                 Bye Bye Bye        0.0408         0.614
# 2                                     Wannabe        0.1010         0.768
# 3             I'll Be Missing You (feat. 112)        0.0522         0.862
# 4  Everybody (Backstreet's Back) - Radio Edit        0.0352         0.731
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 0       213600   0.702           0.00000    6    0.1590    -5.642     0
# 1       200560   0.928           0.00104    8    0.0845    -4.806     0
# 2       173027   0.864           0.00000   11    0.1620    -6.145     1
# 3       301520   0.479           0.00126    7    0.5890    -9.199     1
# 4       225360   0.853           0.00000   10    0.2680    -4.219     0
#
#    speechiness    tempo  time_signature  \
# 0       0.0261   99.031             NaN
# 1       0.0516  172.656             NaN
# 2       0.0324  110.008             NaN
# 3       0.0646  109.878             NaN
# 4       0.0363  108.016             NaN
#
#                                           track_href  valence
# 0  https://api.spotify.com/v1/tracks/6e40mgJiCid5...    0.484
# 1  https://api.spotify.com/v1/tracks/4r8lRYnoOGdE...    0.879
# 2  https://api.spotify.com/v1/tracks/1Je1IMUlBXcx...    0.891
# 3  https://api.spotify.com/v1/tracks/3QHONiXGMGU3...    0.925
# 4  https://api.spotify.com/v1/tracks/1di1BEgJYzPv...    0.605

# %%
df = df.dropna(subset=['time_signature', 'track_href'])

# %%
#df.to_csv('data/master_spotify')
df.head()
# Out:
#                            0        1      2       3      4         5   6   \
# 0  Boulevard of Broken Dreams  0.00552  0.496  262333  0.682  0.000029   8
# 1      Not Ready to Make Nice  0.13400  0.425  237296  0.554  0.000086   6
# 2                       Rehab  0.04730  0.434  213760  0.872  0.000002   0
# 3      Please Read The Letter  0.22400  0.519  353226  0.522  0.342000   9
# 4                Use Somebody  0.00552  0.276  230760  0.715  0.000417   0
#
#        7      8   9       10       11   12  \
# 0  0.0589 -4.095   1  0.0294  167.060  4.0
# 1  0.0963 -4.145   1  0.0298   83.917  4.0
# 2  0.3960 -2.974   1  0.0702   71.515  4.0
# 3  0.1650 -8.626   1  0.0376  144.201  4.0
# 4  0.2010 -5.356   1  0.0432  137.028  4.0
#
#                                                   13     14
# 0  https://api.spotify.com/v1/tracks/5GorCbAP4aL0...  0.474
# 1  https://api.spotify.com/v1/tracks/6LCEyZZHFF4e...  0.288
# 2  https://api.spotify.com/v1/tracks/1L5tZi0izXsi...  0.732
# 3  https://api.spotify.com/v1/tracks/1m5N9YCZL4BX...  0.442
# 4  https://api.spotify.com/v1/tracks/5VGlqQANWDKJ...  0.173

# %%
#df = df[:10]

# %%
db.songs.drop()

# %%
for index, row in df.iterrows():
    collection_songs.insert_one({str(index): list(row.values)})

# %%
df = pd.DataFrame()
collection = db.songs.find()
for doc in collection:
    thevals = list(doc.values())[1] 
    df = df.append(pd.DataFrame([thevals]), ignore_index = True)

# %%
df.head(10)
# Out:
#                                             0        1      2       3      4   \
# 0                   Boulevard of Broken Dreams  0.00552  0.496  262333  0.682
# 1                       Not Ready to Make Nice  0.13400  0.425  237296  0.554
# 2                                        Rehab  0.04730  0.434  213760  0.872
# 3                       Please Read The Letter  0.22400  0.519  353226  0.522
# 4                                 Use Somebody  0.00552  0.276  230760  0.715
# 5                          Rolling in the Deep  0.13100  0.729  228293  0.756
# 6  Somebody That I Used To Know - feat. Kimbra  0.56500  0.857  244973  0.517
# 7                                    Get Lucky  0.03780  0.810  369626  0.793
# 8                                 Stay With Me  0.58800  0.418  172723  0.420
# 9                                  Uptown Funk  0.00801  0.856  269666  0.609
#
#          5   6       7      8   9       10       11   12  \
# 0  0.000029   8  0.0589 -4.095   1  0.0294  167.060  4.0
# 1  0.000086   6  0.0963 -4.145   1  0.0298   83.917  4.0
# 2  0.000002   0  0.3960 -2.974   1  0.0702   71.515  4.0
# 3  0.342000   9  0.1650 -8.626   1  0.0376  144.201  4.0
# 4  0.000417   0  0.2010 -5.356   1  0.0432  137.028  4.0
# 5  0.000000   8  0.0527 -5.119   1  0.0294  104.945  4.0
# 6  0.000195   0  0.1020 -6.972   1  0.0384  129.063  4.0
# 7  0.000002   6  0.0720 -9.404   0  0.0403  116.049  4.0
# 8  0.000064   0  0.1100 -6.444   1  0.0414   84.094  4.0
# 9  0.000082   0  0.0344 -7.223   1  0.0824  114.988  4.0
#
#                                                   13     14
# 0  https://api.spotify.com/v1/tracks/5GorCbAP4aL0...  0.474
# 1  https://api.spotify.com/v1/tracks/6LCEyZZHFF4e...  0.288
# 2  https://api.spotify.com/v1/tracks/1L5tZi0izXsi...  0.732
# 3  https://api.spotify.com/v1/tracks/1m5N9YCZL4BX...  0.442
# 4  https://api.spotify.com/v1/tracks/5VGlqQANWDKJ...  0.173
# 5  https://api.spotify.com/v1/tracks/1CkvWZme3pRg...  0.522
# 6  https://api.spotify.com/v1/tracks/4wCmqSrbyCgx...  0.754
# 7  https://api.spotify.com/v1/tracks/69kOkLUCkxIZ...  0.863
# 8  https://api.spotify.com/v1/tracks/5Nm9ERjJZ5oy...  0.184
# 9  https://api.spotify.com/v1/tracks/32OlwWuMpZ6b...  0.928
