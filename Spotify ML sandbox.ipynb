# %%
from sklearn import tree
import pandas as pd
import os

# %%
df = pd.read_csv(os.path.join("db", "ml_data_spotify.csv"))
df.head()
# Out:
#           artist  duration_ms  acousticness  \
# 0      Green Day       262333       0.00552
# 1   Dixie Chicks       237296       0.13400
# 2  Amy Winehouse       213760       0.04730
# 3   Robert Plant       353226       0.22400
# 4  Kings of Leon       230760       0.00552
#
#                                         analysis_url  danceability  \
# 0  https://api.spotify.com/v1/audio-analysis/5Gor...         0.496
# 1  https://api.spotify.com/v1/audio-analysis/6LCE...         0.425
# 2  https://api.spotify.com/v1/audio-analysis/1L5t...         0.434
# 3  https://api.spotify.com/v1/audio-analysis/1m5N...         0.519
# 4  https://api.spotify.com/v1/audio-analysis/5VGl...         0.276
#
#    duration_ms.1  energy                      id  instrumentalness  key  \
# 0         262333   0.682  5GorCbAP4aL0EJ16frG2hd          0.000029    8
# 1         237297   0.554  6LCEyZZHFF4ebF1Mike1s5          0.000086    6
# 2         213760   0.872  1L5tZi0izXsi5Kk5OJf4W0          0.000002    0
# ...

# %%
target = df['danceability']

# %%
target_names =
